# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/HumanResourceManagementSystem/blob/main/7ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[4,5,6,7]
plt.pyplot(x,y,color="r")
plt.pie([1],color="r")
x1=[10,20,30,40]

plt.pie(x)

plt.slow()
